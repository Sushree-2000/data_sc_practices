# %%
import sys
sys.executable
# Out:
# 'c:\\Users\\subha\\AppData\\Local\\Programs\\Python\\Python313\\python.exe'

# %%
# %%
import numpy as np
np.arange(10)

# %%
np.mean([1, 2, 3])
# Out:
# np.float64(2.0)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# 2.20.0
